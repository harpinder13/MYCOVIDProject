# %% [markdown]
# DAY 1

# %%
Till_Date = 1234
Infected_10_june2020 = 12
Infected_11_june2020 = 2
Infected_12_june2020 = 13
District = "Gwalior"

# %%
per_change= (( Infected_12_june2020- Infected_10_june2020) / Infected_10_june2020)*100

# %%
per_change
# Out:
# 8.333333333333332

# %%
print("% change in the infected cases in given 3 days is {0} in {1}".format(per_change,District))
# Out:
# % change in the infected cases in given 3 days is 8.333333333333332 in Gwalior
