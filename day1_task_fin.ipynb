# %% [markdown]
# DAY 1

# %%
Till_Date = 1234
Infected_10_june2020 = 12
Infected_11_june2020 = 2
Infected_12_june2020 = 13
District = "Gwalior"

# %%
Infected_till_10 = 1234 + 12

print(Infected_till_10)

per_change_10= (( Infected_till_10- Till_Date) / Till_Date)*100
per_change_10
# Out:
# 1246
# 0.9724473257698543

# %%
Infected_till_11 = 1234+12+2
print(Infected_till_11)
per_change_11= (( Infected_till_11-Infected_till_10) / Infected_till_10)*100
per_change_11
# Out:
# 1248
# 0.16051364365971107

# %%
Infected_till_12 = 1234+12+2+13
print(Infected_till_12)
per_change_12= (( Infected_till_12-Infected_till_11) / Infected_till_11)*100
per_change_12
# Out:
# 1261
# 1.0416666666666665

# %%
print("% change in the infected cases on 10th june is {0} in {1}".format(per_change_10,District))
print("% change in the infected cases on 11th june is {0} in {1}".format(per_change_11,District))
print("% change in the infected cases on 12th june is {0} in {1}".format(per_change_12,District))
# Out:
# % change in the infected cases on 10th june is 0.9724473257698543 in Gwalior
# % change in the infected cases on 11th june is 0.16051364365971107 in Gwalior
# % change in the infected cases on 12th june is 1.0416666666666665 in Gwalior
